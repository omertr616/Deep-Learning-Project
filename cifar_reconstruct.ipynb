# %%
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
from torchvision.datasets import CIFAR10
import torch.nn as nn
import data_utils

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
plt.rcParams.update({'font.size': 12})
device
# Out:
# device(type='cuda')

# %%
DATA_DIR = '/datasets/cv_datasets/data'
ds_train = CIFAR10(root=DATA_DIR, download=True, train=True, transform=None)
ds_test = CIFAR10(root=DATA_DIR, download=True, train=False, transform=None)
dl_train, dl_val, dl_test = data_utils.get_data_loaders(train_dataset=ds_train, test_dataset=ds_test, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from cifar10 import encoder, decoder

encoder = encoder.encoder_cifar().to(device)
decoder = decoder.decoder_cifar().to(device)
autoencoder = nn.Sequential(encoder, decoder).to(device)

# %%
import training

try:
    encoder.load_state_dict(torch.load('saved_models/encoder_reconstruction_cifar.pth'))
    decoder.load_state_dict(torch.load('saved_models/decoder_reconstruction_cifar.pth'))
except:
    loss_fn = nn.MSELoss()
    # loss_fn = nn.L1Loss()
    optimizer = torch.optim.Adam(autoencoder.parameters(), lr=5e-4)
    aug_transform = transforms.Compose([
        transforms.RandomResizedCrop(32, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomApply(
            [transforms.ColorJitter(0.8, 0.8, 0.8, 0.2)],
            p=0.2
        )
    ])
    normalize = transforms.Normalize(mean=[0.49139968, 0.48215841, 0.44653091],
                                    std=[0.24703223, 0.24348513, 0.26158784])

    encoder_decoder_trainer = training.AutoencoderTrainer(autoencoder=autoencoder,
                                                            optimizer=optimizer,
                                                            loss_fn=loss_fn,
                                                            device=device,
                                                            transform=aug_transform,
                                                            normalize=normalize)
            
    encoder_decoder_trainer.train(num_epochs=20,
                                dl_train=dl_train,
                                dl_val=dl_val,)

    encoder_decoder_trainer.test(dl_test=dl_test)
    
    torch.save(encoder.state_dict(), 'saved_models/encoder_reconstruction_cifar.pth')
    torch.save(decoder.state_dict(), 'saved_models/decoder_reconstruction_cifar.pth')
# Out:
# /home/omer.trinin/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/omer.trinin/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /home/omer.trinin/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /home/omer.trinin/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /home/omer.trinin/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# --- EPOCH 1/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.27it/s]
# Train loss: 0.288458777633919
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.95it/s]
# Validation loss: 0.21994305732129496
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 1 with validation loss: 0.21994305732129496
# --- EPOCH 2/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.27it/s]
# Train loss: 0.1952608544802801
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.48it/s]
# Validation loss: 0.20070780813694
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 2 with validation loss: 0.20070780813694
# --- EPOCH 3/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.22it/s]
# Train loss: 0.1891108918300068
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 28.99it/s]
# Validation loss: 0.191417184057115
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 3 with validation loss: 0.191417184057115
# --- EPOCH 4/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.25it/s]
# Train loss: 0.17681107393846932
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.52it/s]
# Validation loss: 0.18550178974489623
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 4 with validation loss: 0.18550178974489623
# --- EPOCH 5/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.20it/s]
# Train loss: 0.1722029008140618
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.69it/s]
# Validation loss: 0.18737047156201134
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 6/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.22it/s]
# Train loss: 0.16837533413093875
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.62it/s]
# Validation loss: 0.18138127047804337
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 6 with validation loss: 0.18138127047804337
# --- EPOCH 7/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.20it/s]
# Train loss: 0.1664895071140067
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.63it/s]
# Validation loss: 0.2483018495236771
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 8/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.21it/s]
# Train loss: 0.1667206291934814
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.79it/s]
# Validation loss: 0.17642839328397678
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 8 with validation loss: 0.17642839328397678
# --- EPOCH 9/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.19it/s]
# Train loss: 0.16346733865793794
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.38it/s]
# Validation loss: 0.1826657251089434
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 10/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.20it/s]
# Train loss: 0.1612206233919344
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.44it/s]
# Validation loss: 0.1752753169098987
# Best model saved at epoch 10 with validation loss: 0.1752753169098987
# --- EPOCH 11/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.22it/s]
# Train loss: 0.16091078203383155
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.21it/s]
# Validation loss: 0.17187481873397586
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 11 with validation loss: 0.17187481873397586
# --- EPOCH 12/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.24it/s]
# Train loss: 0.15788535606539386
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.04it/s]
# Validation loss: 0.1719020231615139
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 13/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.22it/s]
# Train loss: 0.1580419581044804
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.64it/s]
# Validation loss: 0.16745477839361264
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 13 with validation loss: 0.16745477839361264
# --- EPOCH 14/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:26<00:00,  8.18it/s]
# Train loss: 0.15684784499039364
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.14it/s]
# Validation loss: 0.17121713674521144
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 15/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.19it/s]
# Train loss: 0.15656997591511093
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.24it/s]
# Validation loss: 0.16711509623859502
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 15 with validation loss: 0.16711509623859502
# --- EPOCH 16/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.20it/s]
# Train loss: 0.15567044944460082
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.50it/s]
# Validation loss: 0.16726167726365826
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 17/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:26<00:00,  8.18it/s]
# Train loss: 0.15488011891614983
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.41it/s]
# Validation loss: 0.17206821053088467
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# --- EPOCH 18/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.21it/s]
# Train loss: 0.15511532897256652
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.50it/s]
# Validation loss: 0.16615374084514908
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 18 with validation loss: 0.16615374084514908
# --- EPOCH 19/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.19it/s]
# Train loss: 0.15533971843648364
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 29.18it/s]
# Validation loss: 0.16525641102579575
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 19 with validation loss: 0.16525641102579575
# --- EPOCH 20/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [01:25<00:00,  8.21it/s]
# Train loss: 0.1538309400731867
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 28.01it/s]
# Validation loss: 0.16503418868855585
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Best model saved at epoch 20 with validation loss: 0.16503418868855585
# Best model loaded.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 157/157 [00:05<00:00, 27.49it/s]
# Test loss: 0.16386299713212213
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from utils import plot_tsne

plot_tsne(model=encoder, dataloader=dl_test, device=device, name='reconstruction_cifar10')

# %%
from cifar10 import classifier

classifier = classifier.ClassifierCifar().to(device)
model = nn.Sequential(encoder, classifier).to(device)
loss_fn = torch.nn.CrossEntropyLoss()

# %%
for param in list(encoder.parameters()):
    param.requires_grad = False
for param in list(classifier.parameters()):
    param.requires_grad = True
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
import training

try:
    classifier.load_state_dict(torch.load('saved_models/classifier_reconstruction_cifar.pth'))
except:
    aug_transform = transforms.Compose([
        transforms.RandomResizedCrop(32, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(p=0.5),
    ])
    normalize = transforms.Normalize(mean=[0.49139968, 0.48215841, 0.44653091],
                                    std=[0.24703223, 0.24348513, 0.26158784])
    
    classifier_trainer = training.ClassifierTrainer(model=model,
                                                optimizer=optimizer,
                                                loss_fn=loss_fn,
                                                device=device)

    classifier_trainer.train(num_epochs=20,
                            dl_train=dl_train,
                            dl_val=dl_val)

    classifier_trainer.test(dl_test=dl_test)
    
    torch.save(classifier.state_dict(), 'saved_models/classifier_reconstruction_cifar.pth')
# Out:
# --- EPOCH 1/20 ---
#   0%|                                                                                                           | 0/704 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.85it/s]
# Train loss: 1.6539765049449422, accuracy: 41.28196022727273
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.67it/s]
# Validation loss: 1.415290381335005, accuracy: 49.545094936708864
# Best model saved at epoch 1 with validation loss: 1.415290381335005
# --- EPOCH 2/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.16it/s]
# Train loss: 1.3913130345330997, accuracy: 50.57927911931818
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.49it/s]
# Validation loss: 1.284229005439372, accuracy: 54.727056962025316
# Best model saved at epoch 2 with validation loss: 1.284229005439372
# --- EPOCH 3/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.23it/s]
# Train loss: 1.2902746619656682, accuracy: 54.40118963068182
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.58it/s]
# Validation loss: 1.2313514072683793, accuracy: 56.60601265822785
# Best model saved at epoch 3 with validation loss: 1.2313514072683793
# --- EPOCH 4/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.19it/s]
# Train loss: 1.2126934073696083, accuracy: 57.01127485795455
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.86it/s]
# Validation loss: 1.1894897411141214, accuracy: 57.950949367088604
# Best model saved at epoch 4 with validation loss: 1.1894897411141214
# --- EPOCH 5/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.12it/s]
# Train loss: 1.1474113372069867, accuracy: 59.51038707386363
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.50it/s]
# Validation loss: 1.1596527197692967, accuracy: 58.88053797468354
# Best model saved at epoch 5 with validation loss: 1.1596527197692967
# --- EPOCH 6/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.11it/s]
# Train loss: 1.0926996434784748, accuracy: 61.48570667613637
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.42it/s]
# Validation loss: 1.1365593279464334, accuracy: 60.52215189873418
# Best model saved at epoch 6 with validation loss: 1.1365593279464334
# --- EPOCH 7/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.16it/s]
# Train loss: 1.037419518963857, accuracy: 63.27237215909091
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.91it/s]
# Validation loss: 1.158051904243759, accuracy: 59.414556962025316
# --- EPOCH 8/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.17it/s]
# Train loss: 0.9909397516907616, accuracy: 65.09232954545455
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.84it/s]
# Validation loss: 1.1099438274962992, accuracy: 61.471518987341774
# Best model saved at epoch 8 with validation loss: 1.1099438274962992
# --- EPOCH 9/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.13it/s]
# Train loss: 0.9412731579081579, accuracy: 66.91228693181819
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.68it/s]
# Validation loss: 1.1069092886357368, accuracy: 62.08465189873418
# Best model saved at epoch 9 with validation loss: 1.1069092886357368
# --- EPOCH 10/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.05it/s]
# Train loss: 0.8891742750155655, accuracy: 68.95862926136364
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.47it/s]
# Validation loss: 1.1156819070441812, accuracy: 61.94620253164557
# --- EPOCH 11/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.15it/s]
# Train loss: 0.8497269856320186, accuracy: 70.21262428977273
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.28it/s]
# Validation loss: 1.0996211782286438, accuracy: 63.15268987341772
# Best model saved at epoch 11 with validation loss: 1.0996211782286438
# --- EPOCH 12/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.96it/s]
# Train loss: 0.807569392491132, accuracy: 71.81507457386364
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.39it/s]
# Validation loss: 1.1080887657177598, accuracy: 62.32199367088607
# --- EPOCH 13/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.92it/s]
# Train loss: 0.7635986592451279, accuracy: 73.291015625
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.66it/s]
# Validation loss: 1.1279239684720583, accuracy: 62.361550632911396
# --- EPOCH 14/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.97it/s]
# Train loss: 0.7198760738088326, accuracy: 75.03773082386364
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.50it/s]
# Validation loss: 1.1477032726324057, accuracy: 62.34177215189873
# --- EPOCH 15/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.95it/s]
# Train loss: 0.6833230284127322, accuracy: 75.9920987215909
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.51it/s]
# Validation loss: 1.1397400302223013, accuracy: 63.034018987341774
# --- EPOCH 16/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.90it/s]
# Train loss: 0.6466958992691203, accuracy: 77.31489701704545
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.57it/s]
# Validation loss: 1.1738852119144005, accuracy: 62.18354430379747
# --- EPOCH 17/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.94it/s]
# Train loss: 0.6108628315427764, accuracy: 78.4423828125
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.33it/s]
# Validation loss: 1.161475649362878, accuracy: 63.56803797468354
# --- EPOCH 18/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.85it/s]
# Train loss: 0.5729649619368667, accuracy: 79.85617897727273
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.11it/s]
# Validation loss: 1.1881632985948007, accuracy: 62.83623417721519
# --- EPOCH 19/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 50.08it/s]
# Train loss: 0.5385721623050895, accuracy: 81.1856356534091
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.71it/s]
# Validation loss: 1.215251936188227, accuracy: 63.034018987341774
# --- EPOCH 20/20 ---
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:14<00:00, 49.87it/s]
# Train loss: 0.5162970039104535, accuracy: 82.04234730113636
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:01<00:00, 60.31it/s]
# Validation loss: 1.2545881799504728, accuracy: 63.15268987341772
# Best model loaded.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 157/157 [00:02<00:00, 59.96it/s]
# Test loss: 1.1988292621199492, accuracy: 63.30613057324841
# WOW!

# %% [markdown]
# ## For quantitative part

# %%
loss_fn = nn.L1Loss()
trainer = training.AutoencoderTrainer(autoencoder=autoencoder, loss_fn=loss_fn, device=device, optimizer=None, normalize=normalize)

# %% [markdown]
# ### Train

# %%
trainer.test(dl_test=dl_train)
# Out:
#   0%|                                                                                                           | 0/704 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 704/704 [00:23<00:00, 30.20it/s]
# Test loss: 0.296032881999219
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Validation

# %%
trainer.test(dl_test=dl_val)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 79/79 [00:02<00:00, 30.35it/s]
# Test loss: 0.29704652594614633
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Test

# %%
trainer.test(dl_test=dl_test)
# Out:
#   0%|                                                                                                           | 0/157 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 157/157 [00:05<00:00, 30.37it/s]
# Test loss: 0.2958777552577341
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
